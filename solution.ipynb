# %%
"""
example function input:
def create_case_statements(df, key_column_list, value_column, naming_column)

key_columns = L1 - L8 in that particular example. Function should be able to adapt to different number of columns and different column names
value_column = [One Hier value] - always one value that all the key columns should match into
naming_column = [One Hier lvl] - name of the column after the case statement is implemented
"""

# %%
import pandas as pd
import numpy as np

# pip install pyjanitor
import janitor

df = pd.read_excel('task_im.xlsx')

# %%
df
# Out:
#                                 L1           L2    L3  L4    L5  L6    L7  L8  \
# 0              DIAPERS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 1                     HAIR SHAMPOO          NaN   NaN NaN   NaN NaN   NaN NaN
# 2               TOTAL AUTO DISH V2          NaN   NaN NaN   NaN NaN   NaN NaN
# 3               BLADES & RAZORS V2          NaN   NaN NaN   NaN NaN   NaN NaN
# 4       DEODORANTS/ANTIPERSPIRANTS          NaN   NaN NaN   NaN NaN   NaN NaN
# 5                HAIR CONDITIONERS          NaN   NaN NaN   NaN NaN   NaN NaN
# 6              FEMININE HYGIENE V3          NaN   NaN NaN   NaN NaN   NaN NaN
# 7       POWERED ORAL CARE CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 8     FABRIC SOFTENERS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 9   LAUNDRY DETERGENTS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 10             FEMALE HAIR REMOVAL          NaN   NaN NaN   NaN NaN   NaN NaN
# ...

# %%
# def f(x):
#     match x:
#         case 'a':
#             return 1
#         case 'b'
#             return 2
#         case 'c"'


#  when L1 and L2 is and L3

# %%
# df.loc[df[1]]
# df.loc[[1,2,3],['L1','L2','L3']]
# df['L3']

# %%
# nawiązanie do kolumny L2, L3 i L4
df.iloc[:,[1,2,3]]
# Out:
#              L2    L3  L4
# 0           NaN   NaN NaN
# 1           NaN   NaN NaN
# 2           NaN   NaN NaN
# 3           NaN   NaN NaN
# 4           NaN   NaN NaN
# 5           NaN   NaN NaN
# 6           NaN   NaN NaN
# 7           NaN   NaN NaN
# 8           NaN   NaN NaN
# 9           NaN   NaN NaN
# 10          NaN   NaN NaN
# 11          NaN   NaN NaN
# 12          NaN   NaN NaN
# 13          NaN   NaN NaN
# 14          NaN   NaN NaN
# 15          NaN   NaN NaN
# 16          NaN   NaN NaN
# 17          NaN   NaN NaN
# 18          NaN   NaN NaN
# 19          NaN   NaN NaN
# 20          NaN   NaN NaN
# 21          NaN   NaN NaN
# 22          NaN   NaN NaN
# 23          NaN   NaN NaN
# 24          NaN   NaN NaN
# 25          NaN   NaN NaN
# 26          NaN   NaN NaN
# 27          NaN   NaN NaN
# 28          NaN   NaN NaN
# 29          NaN   NaN NaN
# 30  MALE/UNISEX   NaN NaN
# 31       FEMALE   NaN NaN
# 32          NaN   NaN NaN
# 33          NaN   NaN NaN
# ...

# %%
# # df.iloc[:,[1,2,3]]
# class my:
#     def __init__(self, df):
#         self.df = df

# a = my(df)

# %%
df.head(5)
# adf = pd.df({})
# Out:
#                            L1   L2   L3  L4   L5  L6   L7  L8 One Hier lvl  \
# 0         DIAPERS V2 CATEGORY  NaN  NaN NaN  NaN NaN  NaN NaN    01-Sector
# 1                HAIR SHAMPOO  NaN  NaN NaN  NaN NaN  NaN NaN    01-Sector
# 2          TOTAL AUTO DISH V2  NaN  NaN NaN  NaN NaN  NaN NaN    01-Sector
# 3          BLADES & RAZORS V2  NaN  NaN NaN  NaN NaN  NaN NaN    01-Sector
# 4  DEODORANTS/ANTIPERSPIRANTS  NaN  NaN NaN  NaN NaN  NaN NaN    01-Sector
#
#          One Hier value
# 0  Baby & Feminine Care
# 1           Beauty Care
# 2    Fabric & Home Care
# 3              Grooming
# 4           Beauty Care

# %%
# df.case_when(
# # condition, value
#     df.L1.eq('DIAPERS V2 CATEGORY') & df.L2.eq(df.L3) & df.L4.eq(df.L5) & df.L6.eq(df.L7), 'Baby & Feminine Care',
#     df.L1.eq('BLADES & RAZORS V3') & df.L2.isin(['FEMALE', 'MALE/UNISEX']), 'Female B&R',
#     0,
#     column_name = '01-Sector'
# )


df.case_when(
# condition, value
    df.L1.eq('HAIR SHAMPOO') & df.L2.isin([np.nan]) , 'Beauty Care',
    df.L1.eq('BLADES & RAZORS V3') & df.L2.isin(['FEMALE', 'MALE/UNISEX']), 'Female B&R',
    df.L1.eq('FEMININE HYGIENE V3') & df.L5.eq(df.L3) & df.L7.eq(df.L3), 'Pads_2',
    0,
    column_name = '01-Sector'
)
# Out:
#                                 L1           L2    L3  L4    L5  L6    L7  L8  \
# 0              DIAPERS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 1                     HAIR SHAMPOO          NaN   NaN NaN   NaN NaN   NaN NaN
# 2               TOTAL AUTO DISH V2          NaN   NaN NaN   NaN NaN   NaN NaN
# 3               BLADES & RAZORS V2          NaN   NaN NaN   NaN NaN   NaN NaN
# 4       DEODORANTS/ANTIPERSPIRANTS          NaN   NaN NaN   NaN NaN   NaN NaN
# 5                HAIR CONDITIONERS          NaN   NaN NaN   NaN NaN   NaN NaN
# 6              FEMININE HYGIENE V3          NaN   NaN NaN   NaN NaN   NaN NaN
# 7       POWERED ORAL CARE CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 8     FABRIC SOFTENERS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 9   LAUNDRY DETERGENTS V2 CATEGORY          NaN   NaN NaN   NaN NaN   NaN NaN
# 10             FEMALE HAIR REMOVAL          NaN   NaN NaN   NaN NaN   NaN NaN
# ...
